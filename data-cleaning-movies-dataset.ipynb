# %%
import pandas as pd
import numpy as np
import re

# %%
# import data
df = pd.read_csv('/kaggle/input/movies-dataset-for-feature-extracion-prediction/movies.csv')
df.head()
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# 4  \nA prequel, set before the events of Army of ...
#
#                                                STARS    VOTES  RunTime Gross
# 0  \n    Director:\nPeter Thorwarth\n| \n    Star...   21,062    121.0   NaN
# 1  \n            \n    Stars:\nChris Wood, \nSara...   17,870     25.0   NaN
# 2  \n            \n    Stars:\nAndrew Lincoln, \n...  885,805     44.0   NaN
# 3  \n            \n    Stars:\nJustin Roiland, \n...  414,849     23.0   NaN
# 4  \n    Director:\nMatthias Schweighöfer\n| \n  ...      NaN      NaN   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     8179 non-null   object
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 703.2+ KB

# %% [markdown]
# ---
# After rechecked the data, I've found that many of records are duplicated even if some columns are different. For example, the movie named "Rick and Morty" have 10 records in total but data in the MOVIES, YEARS and GENRE columns are the same with difference in others.
#
# I've lookup in the internet and found that the reasons could be, 1 movie has many directors or stars so that the different combinations of directors and stars of that movie are considered as a different movie.
#
# Most of each duplicated movies have 3 columns in common which are MOVIES, YEARS and GENRE. So, I've decided to check duplicates from only these 3 columns and keep the record that has the most VOTES. The more VOTES can be interpreted as the more people have faced it in the IMDB.
#
# ---

# %%
# define trim function for string

def trim(s):
    return re.sub('  +', ' ', s).strip() if type(s) == str else s

# %%
# drop duplicates

df2 = df.copy()
df2 = df2.replace({np.nan: None})
df2 = df2.applymap(trim)
df2['VOTES'] = df2['VOTES'].apply(lambda x: int(x.replace(',', '')) if isinstance(x, (str)) else x)
df2 = df2.sort_values(by='VOTES', ascending=False)
df2 = df2.drop_duplicates(subset=['MOVIES', 'YEAR', 'GENRE'])
df2 = df2.sort_index().reset_index(drop=True)
df2
# Out:
#                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 6493                             The Talk     (2010– )
# 6494                       Kajko i Kokosz     (2021– )
# 6495                 God's Favorite Idiot         None
# 6496                              Astérix       (2023)
# 6497                            The House     (2021– )
#
#                              GENRE  RATING  \
# 0         Action, Horror, Thriller     6.1
# 1     Animation, Action, Adventure     5.0
# 2          Drama, Horror, Thriller     8.2
# 3     Animation, Adventure, Comedy     9.2
# 4            Action, Crime, Horror     NaN
# ...                            ...     ...
# 6493                     Talk-Show     NaN
# 6494  Animation, Action, Adventure     7.1
# 6495                        Comedy     NaN
# 6496  Animation, Action, Adventure     NaN
# 6497   Animation, Comedy, Thriller     NaN
#
#                                                ONE-LINE  \
# 0     A woman with a mysterious illness is forced in...
# 1     The war for Eternia begins again in what may b...
# 2     Sheriff Deputy Rick Grimes wakes up from a com...
# 3     An animated series that follows the exploits o...
# 4     A prequel, set before the events of Army of th...
# ...                                                 ...
# 6493            Actor Ralph Macchio (Cobra Kai (2018));
# 6494                                         Add a Plot
# 6495                                         Add a Plot
# 6496                                         Add a Plot
# 6497                                         Add a Plot
#
#                                                   STARS     VOTES  RunTime  \
# 0     Director:\nPeter Thorwarth\n| \n Stars:\nPeri ...   21062.0    121.0
# 1     Stars:\nChris Wood, \nSarah Michelle Gellar, \...   17870.0     25.0
# 2     Stars:\nAndrew Lincoln, \nNorman Reedus, \nMel...  885805.0     44.0
# 3     Stars:\nJustin Roiland, \nChris Parnell, \nSpe...  414849.0     23.0
# 4     Director:\nMatthias Schweighöfer\n| \n Stars:\...       NaN      NaN
# ...                                                 ...       ...      ...
# 6493  Stars:\nSharon Osbourne, \nSheryl Underwood, \...       NaN     38.0
# 6494  Director:\nMichal Sledzinski\n| \n Stars:\nArt...      34.0      NaN
# 6495  Stars:\nLeslie Bibb, \nMelissa McCarthy, \nKev...       NaN      NaN
# 6496                                                          NaN      NaN
# 6497  Stars:\nClaudie Blakley, \nStephanie Cole, \nM...       NaN      NaN
#
#      Gross
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# ...    ...
# 6493  None
# 6494  None
# 6495  None
# 6496  None
# 6497  None
#
# [6498 rows x 9 columns]

# %% [markdown]
# ---
# First, I've noticed that data in the column YEAR are not in the same pattern. From what I've seen, there're 4 patterns of them.
# 1. 1 Year: ####
# 2. \> 1 Year: ####–####
# 3. Ongoing: ####–
# 4. No Year (Blank data)
#
# It would be great if I split the YEAR column into 2 columns which are "Start Year" and "End Year" to satisfy the concept 1 column 1 meaning. I've decided to leave the "End Year" blank if the movie was still ongoing in the time data was collected.
#
# ---

# %%
# insert start_year, end_year
# drop YEAR

start_year = []
end_year = []

for y in df2['YEAR']:
    if isinstance(y, (str)):
        y_to_y = re.search('\d{4}–\d{4}', y)
        y_to = re.search('\d{4}–', y)
        yyyy = re.search('\d{4}', y)
        if bool(y_to_y):
            start_year.append(y_to_y.group()[0:4])
            end_year.append(y_to_y.group()[5:9])
        elif bool(y_to):
            start_year.append(y_to.group()[0:-1])
            end_year.append(None)
        elif bool(yyyy):
            start_year.append(yyyy.group())
            end_year.append(yyyy.group())
        else:
            start_year.append(None)
            end_year.append(None)
    else:
        start_year.append(None)
        end_year.append(None)
        
df2.insert(1, 'start_year', start_year)
df2.insert(2, 'end_year', end_year)
df2 = df2.drop(columns=['YEAR'])
df2
# Out:
#                                    MOVIES start_year end_year  \
# 0                           Blood Red Sky       2021     2021
# 1     Masters of the Universe: Revelation       2021     None
# 2                        The Walking Dead       2010     2022
# 3                          Rick and Morty       2013     None
# 4                         Army of Thieves       2021     2021
# ...                                   ...        ...      ...
# 6493                             The Talk       2010     None
# 6494                       Kajko i Kokosz       2021     None
# 6495                 God's Favorite Idiot       None     None
# 6496                              Astérix       2023     2023
# 6497                            The House       2021     None
#
#                              GENRE  RATING  \
# 0         Action, Horror, Thriller     6.1
# 1     Animation, Action, Adventure     5.0
# 2          Drama, Horror, Thriller     8.2
# 3     Animation, Adventure, Comedy     9.2
# 4            Action, Crime, Horror     NaN
# ...                            ...     ...
# 6493                     Talk-Show     NaN
# 6494  Animation, Action, Adventure     7.1
# 6495                        Comedy     NaN
# 6496  Animation, Action, Adventure     NaN
# 6497   Animation, Comedy, Thriller     NaN
#
#                                                ONE-LINE  \
# 0     A woman with a mysterious illness is forced in...
# 1     The war for Eternia begins again in what may b...
# 2     Sheriff Deputy Rick Grimes wakes up from a com...
# 3     An animated series that follows the exploits o...
# 4     A prequel, set before the events of Army of th...
# ...                                                 ...
# 6493            Actor Ralph Macchio (Cobra Kai (2018));
# 6494                                         Add a Plot
# 6495                                         Add a Plot
# 6496                                         Add a Plot
# 6497                                         Add a Plot
#
#                                                   STARS     VOTES  RunTime  \
# 0     Director:\nPeter Thorwarth\n| \n Stars:\nPeri ...   21062.0    121.0
# 1     Stars:\nChris Wood, \nSarah Michelle Gellar, \...   17870.0     25.0
# 2     Stars:\nAndrew Lincoln, \nNorman Reedus, \nMel...  885805.0     44.0
# 3     Stars:\nJustin Roiland, \nChris Parnell, \nSpe...  414849.0     23.0
# 4     Director:\nMatthias Schweighöfer\n| \n Stars:\...       NaN      NaN
# ...                                                 ...       ...      ...
# 6493  Stars:\nSharon Osbourne, \nSheryl Underwood, \...       NaN     38.0
# 6494  Director:\nMichal Sledzinski\n| \n Stars:\nArt...      34.0      NaN
# 6495  Stars:\nLeslie Bibb, \nMelissa McCarthy, \nKev...       NaN      NaN
# 6496                                                          NaN      NaN
# 6497  Stars:\nClaudie Blakley, \nStephanie Cole, \nM...       NaN      NaN
#
#      Gross
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# ...    ...
# 6493  None
# 6494  None
# 6495  None
# 6496  None
# 6497  None
#
# [6498 rows x 10 columns]

# %%
# check how many and what Genre there are.
exp_genre = df2['GENRE'].str.split(', ', expand=True).rename(columns={0:'genre1', 1:'genre2', 2:'genre3'})
exp_genre
# Out:
#          genre1     genre2     genre3
# 0        Action     Horror   Thriller
# 1     Animation     Action  Adventure
# 2         Drama     Horror   Thriller
# 3     Animation  Adventure     Comedy
# 4        Action      Crime     Horror
# ...         ...        ...        ...
# 6493  Talk-Show       None       None
# 6494  Animation     Action  Adventure
# 6495     Comedy       None       None
# 6496  Animation     Action  Adventure
# 6497  Animation     Comedy   Thriller
#
# [6498 rows x 3 columns]

# %%
# check unique genres
exp_genre_unique = exp_genre.stack().reset_index(drop=True).unique()
pd.Series(exp_genre_unique).sort_values().reset_index(drop=True)
# Out:
# 0          Action
# 1       Adventure
# 2       Animation
# 3       Biography
# 4          Comedy
# 5           Crime
# 6     Documentary
# 7           Drama
# 8          Family
# 9         Fantasy
# 10      Film-Noir
# 11      Game-Show
# 12        History
# 13         Horror
# 14          Music
# 15        Musical
# 16        Mystery
# 17           News
# 18     Reality-TV
# 19        Romance
# 20         Sci-Fi
# 21          Short
# 22          Sport
# 23      Talk-Show
# 24       Thriller
# 25            War
# 26        Western
# dtype: object

# %% [markdown]
# ---
# Each movie has at most 3 genres with 27 unique genre types. There are 2 unique genres looking ambiguous which are "musical" and "music". It should be the same so replace them as "musical" and 26 unique genre types left in total. I will one-hot encode for all 26 genres.
#
# ---

# %%
# replace Music with Musical
exp_genre = exp_genre.replace('Music', 'Musical')
exp_genre
# Out:
#          genre1     genre2     genre3
# 0        Action     Horror   Thriller
# 1     Animation     Action  Adventure
# 2         Drama     Horror   Thriller
# 3     Animation  Adventure     Comedy
# 4        Action      Crime     Horror
# ...         ...        ...        ...
# 6493  Talk-Show       None       None
# 6494  Animation     Action  Adventure
# 6495     Comedy       None       None
# 6496  Animation     Action  Adventure
# 6497  Animation     Comedy   Thriller
#
# [6498 rows x 3 columns]

# %%
# check unique again
exp_genre_unique = exp_genre.stack().reset_index(drop=True).unique()
exp_genre_unique = pd.Series(exp_genre_unique).sort_values().reset_index(drop=True)
exp_genre_unique
# Out:
# 0          Action
# 1       Adventure
# 2       Animation
# 3       Biography
# 4          Comedy
# 5           Crime
# 6     Documentary
# 7           Drama
# 8          Family
# 9         Fantasy
# 10      Film-Noir
# 11      Game-Show
# 12        History
# 13         Horror
# 14        Musical
# 15        Mystery
# 16           News
# 17     Reality-TV
# 18        Romance
# 19         Sci-Fi
# 20          Short
# 21          Sport
# 22      Talk-Show
# 23       Thriller
# 24            War
# 25        Western
# dtype: object

# %%
# insert new 3 genre columns and drop current GENRE
df2 = df2.drop(columns=['GENRE'])
df2.insert(3, 'genre1', exp_genre['genre1'])
df2.insert(4, 'genre2', exp_genre['genre2'])
df2.insert(5, 'genre3', exp_genre['genre3'])
df2
# Out:
#                                    MOVIES start_year end_year     genre1  \
# 0                           Blood Red Sky       2021     2021     Action
# 1     Masters of the Universe: Revelation       2021     None  Animation
# 2                        The Walking Dead       2010     2022      Drama
# 3                          Rick and Morty       2013     None  Animation
# 4                         Army of Thieves       2021     2021     Action
# ...                                   ...        ...      ...        ...
# 6493                             The Talk       2010     None  Talk-Show
# 6494                       Kajko i Kokosz       2021     None  Animation
# 6495                 God's Favorite Idiot       None     None     Comedy
# 6496                              Astérix       2023     2023  Animation
# 6497                            The House       2021     None  Animation
#
#          genre2     genre3  RATING  \
# 0        Horror   Thriller     6.1
# 1        Action  Adventure     5.0
# 2        Horror   Thriller     8.2
# 3     Adventure     Comedy     9.2
# 4         Crime     Horror     NaN
# ...         ...        ...     ...
# 6493       None       None     NaN
# 6494     Action  Adventure     7.1
# 6495       None       None     NaN
# 6496     Action  Adventure     NaN
# 6497     Comedy   Thriller     NaN
#
#                                                ONE-LINE  \
# 0     A woman with a mysterious illness is forced in...
# 1     The war for Eternia begins again in what may b...
# 2     Sheriff Deputy Rick Grimes wakes up from a com...
# 3     An animated series that follows the exploits o...
# 4     A prequel, set before the events of Army of th...
# ...                                                 ...
# 6493            Actor Ralph Macchio (Cobra Kai (2018));
# 6494                                         Add a Plot
# 6495                                         Add a Plot
# 6496                                         Add a Plot
# 6497                                         Add a Plot
#
#                                                   STARS     VOTES  RunTime  \
# 0     Director:\nPeter Thorwarth\n| \n Stars:\nPeri ...   21062.0    121.0
# 1     Stars:\nChris Wood, \nSarah Michelle Gellar, \...   17870.0     25.0
# 2     Stars:\nAndrew Lincoln, \nNorman Reedus, \nMel...  885805.0     44.0
# 3     Stars:\nJustin Roiland, \nChris Parnell, \nSpe...  414849.0     23.0
# 4     Director:\nMatthias Schweighöfer\n| \n Stars:\...       NaN      NaN
# ...                                                 ...       ...      ...
# 6493  Stars:\nSharon Osbourne, \nSheryl Underwood, \...       NaN     38.0
# 6494  Director:\nMichal Sledzinski\n| \n Stars:\nArt...      34.0      NaN
# 6495  Stars:\nLeslie Bibb, \nMelissa McCarthy, \nKev...       NaN      NaN
# 6496                                                          NaN      NaN
# 6497  Stars:\nClaudie Blakley, \nStephanie Cole, \nM...       NaN      NaN
#
#      Gross
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# ...    ...
# 6493  None
# 6494  None
# 6495  None
# 6496  None
# 6497  None
#
# [6498 rows x 12 columns]

# %%
# one-hot enconding for genre
res = {}
for genre in exp_genre_unique:
    res[genre] = df2.loc[:, 'genre1':'genre3'].apply(lambda x: genre in x.to_numpy(), axis=1)
res = pd.DataFrame(res)
res
# Out:
#       Action  Adventure  Animation  Biography  Comedy  Crime  Documentary  \
# 0       True      False      False      False   False  False        False
# 1       True       True       True      False   False  False        False
# 2      False      False      False      False   False  False        False
# 3      False       True       True      False    True  False        False
# 4       True      False      False      False   False   True        False
# ...      ...        ...        ...        ...     ...    ...          ...
# 6493   False      False      False      False   False  False        False
# 6494    True       True       True      False   False  False        False
# 6495   False      False      False      False    True  False        False
# 6496    True       True       True      False   False  False        False
# 6497   False      False       True      False    True  False        False
#
#       Drama  Family  Fantasy  ...   News  Reality-TV  Romance  Sci-Fi  Short  \
# 0     False   False    False  ...  False       False    False   False  False
# 1     False   False    False  ...  False       False    False   False  False
# 2      True   False    False  ...  False       False    False   False  False
# 3     False   False    False  ...  False       False    False   False  False
# 4     False   False    False  ...  False       False    False   False  False
# ...     ...     ...      ...  ...    ...         ...      ...     ...    ...
# 6493  False   False    False  ...  False       False    False   False  False
# 6494  False   False    False  ...  False       False    False   False  False
# 6495  False   False    False  ...  False       False    False   False  False
# 6496  False   False    False  ...  False       False    False   False  False
# 6497  False   False    False  ...  False       False    False   False  False
#
#       Sport  Talk-Show  Thriller    War  Western
# 0     False      False      True  False    False
# 1     False      False     False  False    False
# 2     False      False      True  False    False
# 3     False      False     False  False    False
# 4     False      False     False  False    False
# ...     ...        ...       ...    ...      ...
# 6493  False       True     False  False    False
# 6494  False      False     False  False    False
# 6495  False      False     False  False    False
# 6496  False      False     False  False    False
# 6497  False      False      True  False    False
#
# [6498 rows x 26 columns]

# %%
# insert one-hot encoding after genre3
df2 = pd.concat([df2.loc[:, 'MOVIES':'genre3'], res, df2.loc[:, 'RATING':]], axis=1)
df2
# Out:
#                                    MOVIES start_year end_year     genre1  \
# 0                           Blood Red Sky       2021     2021     Action
# 1     Masters of the Universe: Revelation       2021     None  Animation
# 2                        The Walking Dead       2010     2022      Drama
# 3                          Rick and Morty       2013     None  Animation
# 4                         Army of Thieves       2021     2021     Action
# ...                                   ...        ...      ...        ...
# 6493                             The Talk       2010     None  Talk-Show
# 6494                       Kajko i Kokosz       2021     None  Animation
# 6495                 God's Favorite Idiot       None     None     Comedy
# 6496                              Astérix       2023     2023  Animation
# 6497                            The House       2021     None  Animation
#
#          genre2     genre3  Action  Adventure  Animation  Biography  ...  \
# 0        Horror   Thriller    True      False      False      False  ...
# 1        Action  Adventure    True       True       True      False  ...
# 2        Horror   Thriller   False      False      False      False  ...
# 3     Adventure     Comedy   False       True       True      False  ...
# 4         Crime     Horror    True      False      False      False  ...
# ...         ...        ...     ...        ...        ...        ...  ...
# 6493       None       None   False      False      False      False  ...
# 6494     Action  Adventure    True       True       True      False  ...
# 6495       None       None   False      False      False      False  ...
# 6496     Action  Adventure    True       True       True      False  ...
# 6497     Comedy   Thriller   False      False       True      False  ...
#
#       Talk-Show  Thriller    War  Western  RATING  \
# 0         False      True  False    False     6.1
# 1         False     False  False    False     5.0
# 2         False      True  False    False     8.2
# 3         False     False  False    False     9.2
# 4         False     False  False    False     NaN
# ...         ...       ...    ...      ...     ...
# 6493       True     False  False    False     NaN
# 6494      False     False  False    False     7.1
# 6495      False     False  False    False     NaN
# 6496      False     False  False    False     NaN
# 6497      False      True  False    False     NaN
#
#                                                ONE-LINE  \
# 0     A woman with a mysterious illness is forced in...
# 1     The war for Eternia begins again in what may b...
# 2     Sheriff Deputy Rick Grimes wakes up from a com...
# 3     An animated series that follows the exploits o...
# 4     A prequel, set before the events of Army of th...
# ...                                                 ...
# 6493            Actor Ralph Macchio (Cobra Kai (2018));
# 6494                                         Add a Plot
# 6495                                         Add a Plot
# 6496                                         Add a Plot
# 6497                                         Add a Plot
#
#                                                   STARS     VOTES  RunTime  \
# 0     Director:\nPeter Thorwarth\n| \n Stars:\nPeri ...   21062.0    121.0
# 1     Stars:\nChris Wood, \nSarah Michelle Gellar, \...   17870.0     25.0
# 2     Stars:\nAndrew Lincoln, \nNorman Reedus, \nMel...  885805.0     44.0
# 3     Stars:\nJustin Roiland, \nChris Parnell, \nSpe...  414849.0     23.0
# 4     Director:\nMatthias Schweighöfer\n| \n Stars:\...       NaN      NaN
# ...                                                 ...       ...      ...
# 6493  Stars:\nSharon Osbourne, \nSheryl Underwood, \...       NaN     38.0
# 6494  Director:\nMichal Sledzinski\n| \n Stars:\nArt...      34.0      NaN
# 6495  Stars:\nLeslie Bibb, \nMelissa McCarthy, \nKev...       NaN      NaN
# 6496                                                          NaN      NaN
# 6497  Stars:\nClaudie Blakley, \nStephanie Cole, \nM...       NaN      NaN
#
#       Gross
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# ...     ...
# 6493   None
# 6494   None
# 6495   None
# 6496   None
# 6497   None
#
# [6498 rows x 38 columns]

# %% [markdown]
# ---
# For column ONE-LINE, there are no blank but "Add a Plot" is considered as blank data. So, replace them with the real blank and trim the results.
#
# ---

# %%
# replace 'Add a Plot' to None
df2['ONE-LINE'] = df2['ONE-LINE'].replace('Add a Plot', None)
df2
# Out:
#                                    MOVIES start_year end_year     genre1  \
# 0                           Blood Red Sky       2021     2021     Action
# 1     Masters of the Universe: Revelation       2021     None  Animation
# 2                        The Walking Dead       2010     2022      Drama
# 3                          Rick and Morty       2013     None  Animation
# 4                         Army of Thieves       2021     2021     Action
# ...                                   ...        ...      ...        ...
# 6493                             The Talk       2010     None  Talk-Show
# 6494                       Kajko i Kokosz       2021     None  Animation
# 6495                 God's Favorite Idiot       None     None     Comedy
# 6496                              Astérix       2023     2023  Animation
# 6497                            The House       2021     None  Animation
#
#          genre2     genre3  Action  Adventure  Animation  Biography  ...  \
# 0        Horror   Thriller    True      False      False      False  ...
# 1        Action  Adventure    True       True       True      False  ...
# 2        Horror   Thriller   False      False      False      False  ...
# 3     Adventure     Comedy   False       True       True      False  ...
# 4         Crime     Horror    True      False      False      False  ...
# ...         ...        ...     ...        ...        ...        ...  ...
# 6493       None       None   False      False      False      False  ...
# 6494     Action  Adventure    True       True       True      False  ...
# 6495       None       None   False      False      False      False  ...
# 6496     Action  Adventure    True       True       True      False  ...
# 6497     Comedy   Thriller   False      False       True      False  ...
#
#       Talk-Show  Thriller    War  Western  RATING  \
# 0         False      True  False    False     6.1
# 1         False     False  False    False     5.0
# 2         False      True  False    False     8.2
# 3         False     False  False    False     9.2
# 4         False     False  False    False     NaN
# ...         ...       ...    ...      ...     ...
# 6493       True     False  False    False     NaN
# 6494      False     False  False    False     7.1
# 6495      False     False  False    False     NaN
# 6496      False     False  False    False     NaN
# 6497      False      True  False    False     NaN
#
#                                                ONE-LINE  \
# 0     A woman with a mysterious illness is forced in...
# 1     The war for Eternia begins again in what may b...
# 2     Sheriff Deputy Rick Grimes wakes up from a com...
# 3     An animated series that follows the exploits o...
# 4     A prequel, set before the events of Army of th...
# ...                                                 ...
# 6493            Actor Ralph Macchio (Cobra Kai (2018));
# 6494                                               None
# 6495                                               None
# 6496                                               None
# 6497                                               None
#
#                                                   STARS     VOTES  RunTime  \
# 0     Director:\nPeter Thorwarth\n| \n Stars:\nPeri ...   21062.0    121.0
# 1     Stars:\nChris Wood, \nSarah Michelle Gellar, \...   17870.0     25.0
# 2     Stars:\nAndrew Lincoln, \nNorman Reedus, \nMel...  885805.0     44.0
# 3     Stars:\nJustin Roiland, \nChris Parnell, \nSpe...  414849.0     23.0
# 4     Director:\nMatthias Schweighöfer\n| \n Stars:\...       NaN      NaN
# ...                                                 ...       ...      ...
# 6493  Stars:\nSharon Osbourne, \nSheryl Underwood, \...       NaN     38.0
# 6494  Director:\nMichal Sledzinski\n| \n Stars:\nArt...      34.0      NaN
# 6495  Stars:\nLeslie Bibb, \nMelissa McCarthy, \nKev...       NaN      NaN
# 6496                                                          NaN      NaN
# 6497  Stars:\nClaudie Blakley, \nStephanie Cole, \nM...       NaN      NaN
#
#       Gross
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# ...     ...
# 6493   None
# 6494   None
# 6495   None
# 6496   None
# 6497   None
#
# [6498 rows x 38 columns]

# %% [markdown]
# ---
# There are at most 2 things in the column STARS, so I've decided to split the data into 2 columns which are directors and starts. There are many combinations of the patterns which are 0, 1, 2+ director(s) and 0, 1, 2+ star(s). Because of a lot of names, I won't split the names into columns. All directors go into 1 column and all stars go into 1 another column as well.
#
# ---

# %%
# split directors and stars apart
df2['STARS'] = df2['STARS'].replace('\n', '', regex=True).apply(trim)
res = []

for x in df2['STARS']:
    has_director = bool(re.search('Directors?:', x))
    has_star = bool(re.search('Stars?:', x))
    
    if has_director and has_star:
        director, star = re.search('Directors?:(.*)\|.*Stars?:(.*)', x).groups()
        res.append([director, star])
    elif has_director:
        director = re.search('Directors?:(.*)', x).group(1)
        res.append([director, None])
    elif has_star:
        star = re.search('Stars?:(.*)', x).group(1)
        res.append([None, star])
    else:
        res.append([None, None])

director_star = pd.DataFrame(res, columns=['directors', 'stars'])
director_star
# Out:
#                   directors                                              stars
# 0           Peter Thorwarth  Peri Baumeister, Carl Anton Koch, Alexander Sc...
# 1                      None  Chris Wood, Sarah Michelle Gellar, Lena Headey...
# 2                      None  Andrew Lincoln, Norman Reedus, Melissa McBride...
# 3                      None  Justin Roiland, Chris Parnell, Spencer Grammer...
# 4     Matthias Schweighöfer  Matthias Schweighöfer, Nathalie Emmanuel, Ruby...
# ...                     ...                                                ...
# 6493                   None  Sharon Osbourne, Sheryl Underwood, Carrie Ann ...
# 6494      Michal Sledzinski  Artur Pontek, Michal Piela, Maciej Kosmala, Ja...
# 6495                   None  Leslie Bibb, Melissa McCarthy, Kevin Dunn, Ben...
# 6496                   None                                               None
# 6497                   None  Claudie Blakley, Stephanie Cole, Matthew Goode...
#
# [6498 rows x 2 columns]

# %%
# drop STARS and insert directors and stars
df2 = df2.drop(columns=['STARS'])
df2.insert(34, 'directors', director_star['directors'])
df2.insert(35, 'stars', director_star['stars'])
df2
# Out:
#                                    MOVIES start_year end_year     genre1  \
# 0                           Blood Red Sky       2021     2021     Action
# 1     Masters of the Universe: Revelation       2021     None  Animation
# 2                        The Walking Dead       2010     2022      Drama
# 3                          Rick and Morty       2013     None  Animation
# 4                         Army of Thieves       2021     2021     Action
# ...                                   ...        ...      ...        ...
# 6493                             The Talk       2010     None  Talk-Show
# 6494                       Kajko i Kokosz       2021     None  Animation
# 6495                 God's Favorite Idiot       None     None     Comedy
# 6496                              Astérix       2023     2023  Animation
# 6497                            The House       2021     None  Animation
#
#          genre2     genre3  Action  Adventure  Animation  Biography  ...  \
# 0        Horror   Thriller    True      False      False      False  ...
# 1        Action  Adventure    True       True       True      False  ...
# 2        Horror   Thriller   False      False      False      False  ...
# 3     Adventure     Comedy   False       True       True      False  ...
# 4         Crime     Horror    True      False      False      False  ...
# ...         ...        ...     ...        ...        ...        ...  ...
# 6493       None       None   False      False      False      False  ...
# 6494     Action  Adventure    True       True       True      False  ...
# 6495       None       None   False      False      False      False  ...
# 6496     Action  Adventure    True       True       True      False  ...
# 6497     Comedy   Thriller   False      False       True      False  ...
#
#       Thriller    War  Western  RATING  \
# 0         True  False    False     6.1
# 1        False  False    False     5.0
# 2         True  False    False     8.2
# 3        False  False    False     9.2
# 4        False  False    False     NaN
# ...        ...    ...      ...     ...
# 6493     False  False    False     NaN
# 6494     False  False    False     7.1
# 6495     False  False    False     NaN
# 6496     False  False    False     NaN
# 6497      True  False    False     NaN
#
#                                                ONE-LINE  \
# 0     A woman with a mysterious illness is forced in...
# 1     The war for Eternia begins again in what may b...
# 2     Sheriff Deputy Rick Grimes wakes up from a com...
# 3     An animated series that follows the exploits o...
# 4     A prequel, set before the events of Army of th...
# ...                                                 ...
# 6493            Actor Ralph Macchio (Cobra Kai (2018));
# 6494                                               None
# 6495                                               None
# 6496                                               None
# 6497                                               None
#
#                   directors  \
# 0           Peter Thorwarth
# 1                      None
# 2                      None
# 3                      None
# 4     Matthias Schweighöfer
# ...                     ...
# 6493                   None
# 6494      Michal Sledzinski
# 6495                   None
# 6496                   None
# 6497                   None
#
#                                                   stars     VOTES  RunTime  \
# 0     Peri Baumeister, Carl Anton Koch, Alexander Sc...   21062.0    121.0
# 1     Chris Wood, Sarah Michelle Gellar, Lena Headey...   17870.0     25.0
# 2     Andrew Lincoln, Norman Reedus, Melissa McBride...  885805.0     44.0
# 3     Justin Roiland, Chris Parnell, Spencer Grammer...  414849.0     23.0
# 4     Matthias Schweighöfer, Nathalie Emmanuel, Ruby...       NaN      NaN
# ...                                                 ...       ...      ...
# 6493  Sharon Osbourne, Sheryl Underwood, Carrie Ann ...       NaN     38.0
# 6494  Artur Pontek, Michal Piela, Maciej Kosmala, Ja...      34.0      NaN
# 6495  Leslie Bibb, Melissa McCarthy, Kevin Dunn, Ben...       NaN      NaN
# 6496                                               None       NaN      NaN
# 6497  Claudie Blakley, Stephanie Cole, Matthew Goode...       NaN      NaN
#
#       Gross
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# ...     ...
# 6493   None
# 6494   None
# 6495   None
# 6496   None
# 6497   None
#
# [6498 rows x 39 columns]

# %%
# parse Gross to float
df2['Gross'] = df2['Gross'].str.replace('\$|M', '', regex=True).astype(float)
df2
# Out:
#                                    MOVIES start_year end_year     genre1  \
# 0                           Blood Red Sky       2021     2021     Action
# 1     Masters of the Universe: Revelation       2021     None  Animation
# 2                        The Walking Dead       2010     2022      Drama
# 3                          Rick and Morty       2013     None  Animation
# 4                         Army of Thieves       2021     2021     Action
# ...                                   ...        ...      ...        ...
# 6493                             The Talk       2010     None  Talk-Show
# 6494                       Kajko i Kokosz       2021     None  Animation
# 6495                 God's Favorite Idiot       None     None     Comedy
# 6496                              Astérix       2023     2023  Animation
# 6497                            The House       2021     None  Animation
#
#          genre2     genre3  Action  Adventure  Animation  Biography  ...  \
# 0        Horror   Thriller    True      False      False      False  ...
# 1        Action  Adventure    True       True       True      False  ...
# 2        Horror   Thriller   False      False      False      False  ...
# 3     Adventure     Comedy   False       True       True      False  ...
# 4         Crime     Horror    True      False      False      False  ...
# ...         ...        ...     ...        ...        ...        ...  ...
# 6493       None       None   False      False      False      False  ...
# 6494     Action  Adventure    True       True       True      False  ...
# 6495       None       None   False      False      False      False  ...
# 6496     Action  Adventure    True       True       True      False  ...
# 6497     Comedy   Thriller   False      False       True      False  ...
#
#       Thriller    War  Western  RATING  \
# 0         True  False    False     6.1
# 1        False  False    False     5.0
# 2         True  False    False     8.2
# 3        False  False    False     9.2
# 4        False  False    False     NaN
# ...        ...    ...      ...     ...
# 6493     False  False    False     NaN
# 6494     False  False    False     7.1
# 6495     False  False    False     NaN
# 6496     False  False    False     NaN
# 6497      True  False    False     NaN
#
#                                                ONE-LINE  \
# 0     A woman with a mysterious illness is forced in...
# 1     The war for Eternia begins again in what may b...
# 2     Sheriff Deputy Rick Grimes wakes up from a com...
# 3     An animated series that follows the exploits o...
# 4     A prequel, set before the events of Army of th...
# ...                                                 ...
# 6493            Actor Ralph Macchio (Cobra Kai (2018));
# 6494                                               None
# 6495                                               None
# 6496                                               None
# 6497                                               None
#
#                   directors  \
# 0           Peter Thorwarth
# 1                      None
# 2                      None
# 3                      None
# 4     Matthias Schweighöfer
# ...                     ...
# 6493                   None
# 6494      Michal Sledzinski
# 6495                   None
# 6496                   None
# 6497                   None
#
#                                                   stars     VOTES  RunTime  \
# 0     Peri Baumeister, Carl Anton Koch, Alexander Sc...   21062.0    121.0
# 1     Chris Wood, Sarah Michelle Gellar, Lena Headey...   17870.0     25.0
# 2     Andrew Lincoln, Norman Reedus, Melissa McBride...  885805.0     44.0
# 3     Justin Roiland, Chris Parnell, Spencer Grammer...  414849.0     23.0
# 4     Matthias Schweighöfer, Nathalie Emmanuel, Ruby...       NaN      NaN
# ...                                                 ...       ...      ...
# 6493  Sharon Osbourne, Sheryl Underwood, Carrie Ann ...       NaN     38.0
# 6494  Artur Pontek, Michal Piela, Maciej Kosmala, Ja...      34.0      NaN
# 6495  Leslie Bibb, Melissa McCarthy, Kevin Dunn, Ben...       NaN      NaN
# 6496                                               None       NaN      NaN
# 6497  Claudie Blakley, Stephanie Cole, Matthew Goode...       NaN      NaN
#
#       Gross
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 6493    NaN
# 6494    NaN
# 6495    NaN
# 6496    NaN
# 6497    NaN
#
# [6498 rows x 39 columns]

# %%
# lowercase the columns' names
df2.columns = [c.lower() for c in df2.columns]
df2
# Out:
#                                    movies start_year end_year     genre1  \
# 0                           Blood Red Sky       2021     2021     Action
# 1     Masters of the Universe: Revelation       2021     None  Animation
# 2                        The Walking Dead       2010     2022      Drama
# 3                          Rick and Morty       2013     None  Animation
# 4                         Army of Thieves       2021     2021     Action
# ...                                   ...        ...      ...        ...
# 6493                             The Talk       2010     None  Talk-Show
# 6494                       Kajko i Kokosz       2021     None  Animation
# 6495                 God's Favorite Idiot       None     None     Comedy
# 6496                              Astérix       2023     2023  Animation
# 6497                            The House       2021     None  Animation
#
#          genre2     genre3  action  adventure  animation  biography  ...  \
# 0        Horror   Thriller    True      False      False      False  ...
# 1        Action  Adventure    True       True       True      False  ...
# 2        Horror   Thriller   False      False      False      False  ...
# 3     Adventure     Comedy   False       True       True      False  ...
# 4         Crime     Horror    True      False      False      False  ...
# ...         ...        ...     ...        ...        ...        ...  ...
# 6493       None       None   False      False      False      False  ...
# 6494     Action  Adventure    True       True       True      False  ...
# 6495       None       None   False      False      False      False  ...
# 6496     Action  Adventure    True       True       True      False  ...
# 6497     Comedy   Thriller   False      False       True      False  ...
#
#       thriller    war  western  rating  \
# 0         True  False    False     6.1
# 1        False  False    False     5.0
# 2         True  False    False     8.2
# 3        False  False    False     9.2
# 4        False  False    False     NaN
# ...        ...    ...      ...     ...
# 6493     False  False    False     NaN
# 6494     False  False    False     7.1
# 6495     False  False    False     NaN
# 6496     False  False    False     NaN
# 6497      True  False    False     NaN
#
#                                                one-line  \
# 0     A woman with a mysterious illness is forced in...
# 1     The war for Eternia begins again in what may b...
# 2     Sheriff Deputy Rick Grimes wakes up from a com...
# 3     An animated series that follows the exploits o...
# 4     A prequel, set before the events of Army of th...
# ...                                                 ...
# 6493            Actor Ralph Macchio (Cobra Kai (2018));
# 6494                                               None
# 6495                                               None
# 6496                                               None
# 6497                                               None
#
#                   directors  \
# 0           Peter Thorwarth
# 1                      None
# 2                      None
# 3                      None
# 4     Matthias Schweighöfer
# ...                     ...
# 6493                   None
# 6494      Michal Sledzinski
# 6495                   None
# 6496                   None
# 6497                   None
#
#                                                   stars     votes  runtime  \
# 0     Peri Baumeister, Carl Anton Koch, Alexander Sc...   21062.0    121.0
# 1     Chris Wood, Sarah Michelle Gellar, Lena Headey...   17870.0     25.0
# 2     Andrew Lincoln, Norman Reedus, Melissa McBride...  885805.0     44.0
# 3     Justin Roiland, Chris Parnell, Spencer Grammer...  414849.0     23.0
# 4     Matthias Schweighöfer, Nathalie Emmanuel, Ruby...       NaN      NaN
# ...                                                 ...       ...      ...
# 6493  Sharon Osbourne, Sheryl Underwood, Carrie Ann ...       NaN     38.0
# 6494  Artur Pontek, Michal Piela, Maciej Kosmala, Ja...      34.0      NaN
# 6495  Leslie Bibb, Melissa McCarthy, Kevin Dunn, Ben...       NaN      NaN
# 6496                                               None       NaN      NaN
# 6497  Claudie Blakley, Stephanie Cole, Matthew Goode...       NaN      NaN
#
#       gross
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 6493    NaN
# 6494    NaN
# 6495    NaN
# 6496    NaN
# 6497    NaN
#
# [6498 rows x 39 columns]

# %%
# show duplicated movies (subset = ['movies']) to check if it's different in 3 first columns but really different or not.
df2[df2.duplicated(subset=['movies'], keep=False)].sort_values(by='movies')
# Out:
#                             movies start_year end_year       genre1   genre2  \
# 2171  Amend: The Fight for America       2021     2021  Documentary  History
# 5954  Amend: The Fight for America       2021     2021  Documentary     None
# 5077                       Astérix       None     None    Animation   Action
# 6496                       Astérix       2023     2023    Animation   Action
# 128     Avatar: The Last Airbender       2005     2008    Animation   Action
# ...                            ...        ...      ...          ...      ...
# 3771                      Verónica       2017     2017        Drama  Mystery
# 1321                    Wanderlust       2018     None        Drama     None
# 5459                    Wanderlust       2006     2006  Documentary  History
# 1526                     Wednesday       None     None       Comedy   Family
# 5448                     Wednesday       None     None         None     None
#
#          genre3  action  adventure  animation  biography  ...  thriller  \
# 2171       None   False      False      False      False  ...     False
# 5954       None   False      False      False      False  ...     False
# 5077  Adventure    True       True       True      False  ...     False
# 6496  Adventure    True       True       True      False  ...     False
# 128   Adventure    True       True       True      False  ...     False
# ...         ...     ...        ...        ...        ...  ...       ...
# 3771   Thriller   False      False      False      False  ...      True
# 1321       None   False      False      False      False  ...     False
# 5459       None   False      False      False      False  ...     False
# 1526    Fantasy   False      False      False      False  ...     False
# 5448       None   False      False      False      False  ...     False
#
#         war  western  rating  \
# 2171  False    False     7.9
# 5954  False    False     6.2
# 5077  False    False     NaN
# 6496  False    False     NaN
# 128   False    False     9.3
# ...     ...      ...     ...
# 3771  False    False     5.9
# 1321  False    False     7.1
# 5459  False    False     6.6
# 1526  False    False     NaN
# 5448  False    False     NaN
#
#                                                one-line  \
# 2171  Will Smith hosts this look at the evolving, of...
# 5954                                               None
# 5077  In the glory days of the Roman Empire, one vil...
# 6496                                               None
# 128   In a war-torn world of elemental magic, a youn...
# ...                                                 ...
# 3771  A female Psychologist who has stopped practici...
# 1321  A therapist tries to save her marriage after a...
# 5459  A documentary on road movies and their effect ...
# 1526  A modernized live-action version of 'The Addam...
# 5448  Follows Wednesday Addams' years as a student, ...
#
#                                       directors  \
# 2171                                       None
# 5954                                       None
# 5077                                       None
# 6496                                       None
# 128                                        None
# ...                                         ...
# 3771  Carlos Algara, Alejandro Martinez-Beltran
# 1321                                       None
# 5459      Shari Springer Berman, Robert Pulcini
# 1526                                       None
# 5448                                       None
#
#                                                   stars     votes  runtime  \
# 2171  Will Smith, Bryan Stevenson, Larry Wilmore, Sa...    1068.0      NaN
# 5954                                         Will Smith      16.0      NaN
# 5077                                               None       NaN      NaN
# 6496                                               None       NaN      NaN
# 128   Dee Bradley Baker, Zach Tyler, Mae Whitman, Ja...  265845.0     23.0
# ...                                                 ...       ...      ...
# 3771  Olga Segura, Arcelia Ramírez, Sofía Garza, Hor...    1342.0     81.0
# 1321  Toni Collette, Steven Mackintosh, Joe Hurst, E...    4825.0     60.0
# 5459  Allison Anders, Jeanine Basinger, Robert Bento...     122.0     84.0
# 1526                                       Jenna Ortega       NaN      NaN
# 5448                                               None       NaN      NaN
#
#       gross
# 2171    NaN
# 5954    NaN
# 5077    NaN
# 6496    NaN
# 128     NaN
# ...     ...
# 3771    NaN
# 1321    NaN
# 5459    NaN
# 1526    NaN
# 5448    NaN
#
# [144 rows x 39 columns]

# %%
# how many number of movies that have duplicates.
print(df2[df2.duplicated(subset=['movies'], keep=False)].sort_values(by='movies')['movies'].unique())
print(df2[df2.duplicated(subset=['movies'], keep=False)].sort_values(by='movies')['movies'].unique().shape)

# there are 69 movies that have duplicates but different in either year or genre 🤔🤔
# it's a small part of movies I've got. So, I've decided to drop these duplicated rows by keeping the most votes one.
# Out:
# ['Amend: The Fight for America' 'Astérix' 'Avatar: The Last Airbender'
#  'Away' 'Bad Blood' 'Beauty and the Beast' 'Blackout' 'Blood Brother'
#  'Bodyguard' 'Boku dake ga inai machi' 'Braqueurs' 'Carmen Sandiego'
#  'Daybreak' 'Eden' 'Exatlon Challenge' 'Extracurricular' 'Fearless'
#  'Freedom' 'Garbage' 'Glória' 'Hagane no renkinjutsushi'
#  'Happiness Ever After' 'Heartbreak High' 'Heist' 'Hit and Run' 'Home'
#  'Home for Christmas' 'House Arrest' 'Into the Night' 'Jinn' 'Jonas'
#  'Kakegurui' 'Kingdom' 'Ludo' 'Mai' 'Malibu Rescue' 'Maska' 'Matilda'
#  'Mob Psycho 100' 'One of Us' 'Painkiller' 'Paranoid' 'Paranormal'
#  'Perdida' 'Private Life' 'Revenge' "Rosemary's Baby" 'Safe' 'Security'
#  'Sexy Beasts' 'Snowpiercer' 'Sword Art Online' 'Tales of the City'
#  'The House' 'The Legend of Cocaine Island' 'The Lincoln Lawyer'
#  'The Oscars' 'The Pentaverate' 'The Silence' 'The Stranger' 'The Watcher'
#  'The Whole Truth' 'Titans' 'True Story' 'Ultraman' 'Undercover'
#  'Verónica' 'Wanderlust' 'Wednesday']
# (69,)

# %%
# save the 69 movies duplicates version
df2.to_csv('./cleaned_movie_dataset_69_movies_duplicated.csv', index_label='index')

# %%
# make unique movies version
df3 = df2.sort_values(by='votes').drop_duplicates(subset=['movies']).sort_index().reset_index(drop=True)
df3
# Out:
#                                    movies start_year end_year     genre1  \
# 0                           Blood Red Sky       2021     2021     Action
# 1     Masters of the Universe: Revelation       2021     None  Animation
# 2                        The Walking Dead       2010     2022      Drama
# 3                          Rick and Morty       2013     None  Animation
# 4                         Army of Thieves       2021     2021     Action
# ...                                   ...        ...      ...        ...
# 6418                         Son of Abish       2014     None     Comedy
# 6419             Dad Stop Embarrassing Me       2021     2021     Comedy
# 6420                             The Talk       2010     None  Talk-Show
# 6421                       Kajko i Kokosz       2021     None  Animation
# 6422                 God's Favorite Idiot       None     None     Comedy
#
#          genre2     genre3  action  adventure  animation  biography  ...  \
# 0        Horror   Thriller    True      False      False      False  ...
# 1        Action  Adventure    True       True       True      False  ...
# 2        Horror   Thriller   False      False      False      False  ...
# 3     Adventure     Comedy   False       True       True      False  ...
# 4         Crime     Horror    True      False      False      False  ...
# ...         ...        ...     ...        ...        ...        ...  ...
# 6418  Talk-Show       None   False      False      False      False  ...
# 6419     Family       None   False      False      False      False  ...
# 6420       None       None   False      False      False      False  ...
# 6421     Action  Adventure    True       True       True      False  ...
# 6422       None       None   False      False      False      False  ...
#
#       thriller    war  western  rating  \
# 0         True  False    False     6.1
# 1        False  False    False     5.0
# 2         True  False    False     8.2
# 3        False  False    False     9.2
# 4        False  False    False     NaN
# ...        ...    ...      ...     ...
# 6418     False  False    False     NaN
# 6419     False  False    False     5.7
# 6420     False  False    False     NaN
# 6421     False  False    False     7.1
# 6422     False  False    False     NaN
#
#                                                one-line  \
# 0     A woman with a mysterious illness is forced in...
# 1     The war for Eternia begins again in what may b...
# 2     Sheriff Deputy Rick Grimes wakes up from a com...
# 3     An animated series that follows the exploits o...
# 4     A prequel, set before the events of Army of th...
# ...                                                 ...
# 6418  On this episode, catch Abhishek Bachchan and I...
# 6419  After Sasha moves in with Brian, a mortifying ...
# 6420            Actor Ralph Macchio (Cobra Kai (2018));
# 6421                                               None
# 6422                                               None
#
#                   directors  \
# 0           Peter Thorwarth
# 1                      None
# 2                      None
# 3                      None
# 4     Matthias Schweighöfer
# ...                     ...
# 6418                   None
# 6419        Ken Whittingham
# 6420                   None
# 6421      Michal Sledzinski
# 6422                   None
#
#                                                   stars     votes  runtime  \
# 0     Peri Baumeister, Carl Anton Koch, Alexander Sc...   21062.0    121.0
# 1     Chris Wood, Sarah Michelle Gellar, Lena Headey...   17870.0     25.0
# 2     Andrew Lincoln, Norman Reedus, Melissa McBride...  885805.0     44.0
# 3     Justin Roiland, Chris Parnell, Spencer Grammer...  414849.0     23.0
# 4     Matthias Schweighöfer, Nathalie Emmanuel, Ruby...       NaN      NaN
# ...                                                 ...       ...      ...
# 6418  Abish Mathew, Abhishek Bachchan, Inayat Verma,...       NaN      NaN
# 6419  Jamie Foxx, David Alan Grier, Kyla-Drew, Porsc...      98.0      NaN
# 6420  Sharon Osbourne, Sheryl Underwood, Carrie Ann ...       NaN     38.0
# 6421  Artur Pontek, Michal Piela, Maciej Kosmala, Ja...      34.0      NaN
# 6422  Leslie Bibb, Melissa McCarthy, Kevin Dunn, Ben...       NaN      NaN
#
#       gross
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 6418    NaN
# 6419    NaN
# 6420    NaN
# 6421    NaN
# 6422    NaN
#
# [6423 rows x 39 columns]

# %%
# from 6498 rows to 6423 rows which are unique movie names, save this as another csv.
df3.to_csv('./cleaned_movie_dataset_no_duplicates.csv', index_label='index')
